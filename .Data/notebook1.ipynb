# %%
import pandas as pd

# %%
df = pd.read_csv('World-happiness-report-updated_2024.csv', encoding='latin1')
df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.5                         0.718       0.164
# 1                              50.8                         0.679       0.187
# 2                              51.1                         0.600       0.118
# 3                              51.4                         0.496       0.160
# 4                              51.7                         0.531       0.234
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2363 non-null   object
#  1   year                              2363 non-null   int64
#  2   Life Ladder                       2363 non-null   float64
#  3   Log GDP per capita                2335 non-null   float64
#  4   Social support                    2350 non-null   float64
#  5   Healthy life expectancy at birth  2300 non-null   float64
#  6   Freedom to make life choices      2327 non-null   float64
#  7   Generosity                        2282 non-null   float64
#  8   Perceptions of corruption         2238 non-null   float64
#  9   Positive affect                   2339 non-null   float64
#  10  Negative affect                   2347 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2363.000000  2363.000000         2335.000000     2350.000000
# mean   2014.763860     5.483566            9.399671        0.809369
# std       5.059436     1.125522            1.152069        0.121212
# min    2005.000000     1.281000            5.527000        0.228000
# 25%    2011.000000     4.647000            8.506500        0.744000
# 50%    2015.000000     5.449000            9.503000        0.834500
# 75%    2019.000000     6.323500           10.392500        0.904000
# max    2023.000000     8.019000           11.676000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2300.000000                   2327.000000
# mean                          63.401828                      0.750282
# std                            6.842644                      0.139357
# min                            6.720000                      0.228000
# ...

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of       Country name   year  Life Ladder  Log GDP per capita  Social support  \
# 0            False  False        False               False           False
# 1            False  False        False               False           False
# 2            False  False        False               False           False
# 3            False  False        False               False           False
# 4            False  False        False               False           False
# ...            ...    ...          ...                 ...             ...
# 2358         False  False        False               False           False
# 2359         False  False        False               False           False
# 2360         False  False        False               False           False
# 2361         False  False        False               False           False
# 2362         False  False        False               False           False
#
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 13    Afghanistan  2022        1.281                 NaN           0.228
# 14    Afghanistan  2023        1.446                 NaN           0.368
# 31        Algeria  2010        5.464               9.306             NaN
# 34        Algeria  2014        6.355               9.355           0.818
# 35        Algeria  2016        5.341               9.383           0.749
# ...           ...   ...          ...                 ...             ...
# 2314        Yemen  2007        4.477               8.212           0.825
# 2322        Yemen  2016        3.826               7.552           0.775
# 2323        Yemen  2017        3.254               7.243           0.790
# 2326        Yemen  2022        3.590                 NaN           0.872
# 2327        Yemen  2023        3.532                 NaN           0.825
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
numeric_cols= [
    'Life Ladder', 
    'Log GDP per capita', 
    'Social support', 
    'Healthy life expectancy at birth', 
    'Freedom to make life choices', 
    'Generosity', 
    'Perceptions of corruption', 
    'Positive affect', 
    'Negative affect'
]

#filling the missing areas with median values 

for col in numeric_cols:
    df[col] = df[col].fillna(df[col].median())


print(df[numeric_cols].isnull().sum)
# Out:
# <bound method DataFrame.sum of       Life Ladder  Log GDP per capita  Social support  \
# 0           False               False           False
# 1           False               False           False
# 2           False               False           False
# 3           False               False           False
# 4           False               False           False
# ...           ...                 ...             ...
# 2358        False               False           False
# 2359        False               False           False
# 2360        False               False           False
# 2361        False               False           False
# 2362        False               False           False
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                                False                         False
# 1                                False                         False
# 2                                False                         False
# ...

# %%
df.head(200)
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0    Afghanistan  2008        3.724               7.350           0.451
# 1    Afghanistan  2009        4.402               7.509           0.552
# 2    Afghanistan  2010        4.758               7.614           0.539
# 3    Afghanistan  2011        3.832               7.581           0.521
# 4    Afghanistan  2012        3.783               7.661           0.521
# ..           ...   ...          ...                 ...             ...
# 195        Benin  2011        3.870               7.876           0.477
# 196        Benin  2012        3.193               7.894           0.523
# 197        Benin  2013        3.479               7.935           0.577
# 198        Benin  2014        3.347               7.967           0.506
# 199        Benin  2015        3.625               7.955           0.434
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
#rename the columns for better readability

df.rename(columns={
    'Log GDP per capita' : 'GDP',
    'Country name' : 'Country',
    'Healthy life expectancy at birth' : 'Life Expectancy',
    'Perceptions of corruption' : 'Corruption',
    'Freedom to make life choices': 'Freedom'

},
          inplace=True)


df.head(200)
# Out:
#          Country  year  Life Ladder    GDP  Social support  Life Expectancy  \
# 0    Afghanistan  2008        3.724  7.350           0.451            50.50
# 1    Afghanistan  2009        4.402  7.509           0.552            50.80
# 2    Afghanistan  2010        4.758  7.614           0.539            51.10
# 3    Afghanistan  2011        3.832  7.581           0.521            51.40
# 4    Afghanistan  2012        3.783  7.661           0.521            51.70
# ..           ...   ...          ...    ...             ...              ...
# 195        Benin  2011        3.870  7.876           0.477            53.26
# 196        Benin  2012        3.193  7.894           0.523            53.52
# 197        Benin  2013        3.479  7.935           0.577            53.78
# 198        Benin  2014        3.347  7.967           0.506            54.04
# 199        Benin  2015        3.625  7.955           0.434            54.30
#
# ...

# %%
#sorting by the year 

df['year'] = pd.to_numeric(df['year'], errors='coerce')
df_sorted = df.sort_values(by='year', ascending=False)
df_sorted = df_sorted.reset_index(drop=True) #removes the index where it shows the countries list position in the database

df_sorted.head()
# Out:
#        Country  year  Life Ladder    GDP  Social support  Life Expectancy  \
# 0  Afghanistan  2023        1.446  9.503           0.368             55.2
# 1      Albania  2023        5.445  9.689           0.691             69.2
# 2     Zimbabwe  2023        3.572  7.679           0.694             55.0
# 3      Vietnam  2023        6.325  9.392           0.845             65.7
# 4       Zambia  2023        3.686  8.115           0.664             56.1
#
#    Freedom  Generosity  Corruption  Positive affect  Negative affect
# 0    0.228      -0.022       0.738            0.261            0.460
# 1    0.872       0.068       0.855            0.597            0.314
# 2    0.735      -0.069       0.757            0.610            0.179
# 3    0.956      -0.159       0.655            0.710            0.120
# 4    0.854       0.092       0.814            0.653            0.359

# %%
import matplotlib.pyplot as plt

#show the top 10 by the 'Positive affect' 

top10 = df.sort_values(by='Positive affect', ascending=False).head(22)

plt.figure(figsize=(13,7))
plt.bar(top10['Country'], top10['Positive affect'], color="orange")
plt.xlabel('Positive affect')
plt.title('Top 10 countries with positive affect')
plt.text(0.5, -0.2, 
         'Positive affect refers to the frequency of positive emotions experienced in daily life, such as enjoyment, laughter, and interest', 
         ha='center', va='bottom', transform=plt.gca().transAxes, fontsize=10)
plt.show()

# %%
df.to_csv('world_happiness_2024_clean.csv', index=False)

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\mohdl\Desktop\World-Happiness-Dataset\.Data
